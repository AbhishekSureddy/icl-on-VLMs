# %%
import os
import pickle
import json
from tqdm import tqdm
import os.path as osp
import re
from io import BytesIO
import argparse
import numpy as np

import requests
import torch
from PIL import Image

from llava.constants import (
    DEFAULT_IM_END_TOKEN,
    DEFAULT_IM_START_TOKEN,
    DEFAULT_IMAGE_TOKEN,
    IMAGE_PLACEHOLDER,
    IMAGE_TOKEN_INDEX,
)
from llava.conversation import SeparatorStyle, conv_templates
from llava.mm_utils import KeywordsStoppingCriteria, get_model_name_from_path, process_images, tokenizer_image_token
from llava.model.builder import load_pretrained_model
from llava.utils import disable_torch_init
from eval_datasets import CaptionDataset
from rice import RICES


# arg_parser = argparse.ArgumentParser()
# arg_parser.add_argument(
#     "--model_name_or_path",
#     type=str,
#     default= "Efficient-Large-Model/VILA1.5-13b",
#     help="vila model name or path"
# )
# arg_parser.add_argument(
#     "--n_shots",
#     type=int,
#     help="number of incontext examples",
# )
# arg_parser.add_argument(
#     "--use_random",
#     action="store_true",
#     help="Pass in a list of MMC4 shards in the format path_to_shard/shard_{0..23098}.zip",
# )
# arg_parser.add_argument(
#     "--n_random",
#     type=int,
#     default=0,
#     help="number of random incontext examples",
# )
# arg_parser.add_argument(
#     "--save_path",
#     type=str,
#     help="where to save model outputs",
# )


# args = arg_parser.parse_args()

# input args
model_name_or_path = "Efficient-Large-Model/VILA1.5-13b"
train_annotations_path = "/home/asureddy_umass_edu/cs682/dataset/annotations/captions_train2017.json"
train_image_dir_path = "/scratch/workspace/asureddy_umass_edu-llm_alignment/dataset/train2017"
val_annotations_path = "/home/asureddy_umass_edu/cs682/dataset/annotations/captions_val2017.json"
val_image_dir_path = "/scratch/workspace/asureddy_umass_edu-llm_alignment/dataset/val2017"
rice_cached_features_path = "/scratch/workspace/asureddy_umass_edu-llm_alignment/features-cache/coco_train.pkl" 

train_dataset = CaptionDataset(train_image_dir_path, train_annotations_path)
val_dataset = CaptionDataset(val_image_dir_path, val_annotations_path)
if rice_cached_features_path:
    with open(rice_cached_features_path, 'rb') as f:
        rice_cached_features = pickle.load(f)

retriever = RICES(train_dataset, 'cpu',1, cached_features=rice_cached_features)

model_name = get_model_name_from_path(model_name_or_path)

# tokenizer, model, image_processor, context_len = load_pretrained_model(model_name_or_path, model_name, None)
# image_token_se = DEFAULT_IM_START_TOKEN + DEFAULT_IMAGE_TOKEN + DEFAULT_IM_END_TOKEN

# conv_mode = "hermes-2" # for vila-40b
# llava_v0 for vila-13b
def get_output_for_query(query, imgs, conv_mode="llava_v1",max_new_tokens=5):
    query = re.sub(IMAGE_PLACEHOLDER, DEFAULT_IMAGE_TOKEN, query)
    # conv_mode = "hermes-2"
    conv = conv_templates[conv_mode].copy()
    conv.append_message(conv.roles[0], query)
    conv.append_message(conv.roles[1], None)
    prompt = conv.get_prompt()
    
    images_tensor = process_images(imgs, image_processor, model.config).to(model.device, dtype=torch.float16)
    input_ids = tokenizer_image_token(prompt, tokenizer, IMAGE_TOKEN_INDEX, return_tensors="pt").unsqueeze(0).cuda()
    stop_str = conv.sep if conv.sep_style != SeparatorStyle.TWO else conv.sep2
    keywords = [stop_str]
    stopping_criteria = KeywordsStoppingCriteria(keywords, tokenizer, input_ids)
    
    # print(images_tensor.shape)
    temperature = 0.2
    num_beams = 1
    top_p = 0.95
    max_new_tokens = max_new_tokens
    with torch.inference_mode():
        output_ids = model.generate(
            input_ids,
            images=[
                images_tensor,
            ],
            do_sample=True if temperature > 0 else False,
            temperature=temperature,
            top_p=top_p,
            num_beams=num_beams,
            max_new_tokens=max_new_tokens,
            use_cache=True,
            stopping_criteria=[stopping_criteria],
        )
    
    outputs = tokenizer.batch_decode(output_ids, skip_special_tokens=True)[0]
    outputs = outputs.strip()
    # print(outputs)
    if outputs.endswith(stop_str):
        outputs = outputs[: -len(stop_str)]
    outputs = outputs.strip()
    # print(outputs)
    print(f"query: {query}")
    print(f"caption: {outputs}")
    return outputs

def get_n_shot_demonstrations(item, n=2, use_random=True, n_random=0):
    if n==0: return [[]]
    if use_random:
        train_idxs = list(np.random.choice(len(train_dataset),n))
        icl_demonstrs = [[train_dataset[idx] for idx in train_idxs]]
    else:
        icl_demonstrs = []
        if n_random:
            train_idxs = list(np.random.choice(len(train_dataset),n_random))
            icl_demonstrs = [train_dataset[idx] for idx in train_idxs]
        icl_demonstrs = [icl_demonstrs + retriever.find([item['image']],n-n_random)[0]]
        
    return icl_demonstrs

def construct_vqa_query(query_items, icl_demonstrs_list):
    querys, im_lists = [], []
    for query_item,icl_demonstrs in zip(query_items, icl_demonstrs_list):
        # query = "Answer the questions in one or two words: "
        # query = "Instruction: Below are examples of images with their captions. Use the examples to understand the relationship between the image's content and its description. After the examples, a new image will be provided. Generate a caption that accurately describes the new image."
        query = ""
        images = []
        for item in icl_demonstrs:
            query += f"  Caption: {item['caption']} "
            images.append(item['image'])
        images.append(query_item['image'])
        query += f" Caption: "
        querys.append(query)
        im_lists.append(images)
    return querys, im_lists

def get_output(item, n= 2, use_random= False, n_random=0):

    icl_demonstrs = get_n_shot_demonstrations(item, n, use_random, n_random)
    querys, im_lists = construct_vqa_query([item], icl_demonstrs)
    
    return get_output_for_query(querys[0], im_lists[0],"llava_v1",20)

# %%
# conv_mode = "hermes-2" # for vila-40b
def get_output_for_query(query, imgs, conv_mode="hermes-2",max_new_tokens=50):
    query = re.sub(IMAGE_PLACEHOLDER, DEFAULT_IMAGE_TOKEN, query)
    # conv_mode = "hermes-2"
    conv = conv_templates[conv_mode].copy()
    conv.append_message(conv.roles[0], query)
    conv.append_message(conv.roles[1], None)
    prompt = conv.get_prompt()
    
    images_tensor = process_images(imgs, image_processor, model.config).to(model.device, dtype=torch.float16)
    input_ids = tokenizer_image_token(prompt, tokenizer, IMAGE_TOKEN_INDEX, return_tensors="pt").unsqueeze(0).cuda()
    stop_str = conv.sep if conv.sep_style != SeparatorStyle.TWO else conv.sep2
    keywords = [stop_str]
    stopping_criteria = KeywordsStoppingCriteria(keywords, tokenizer, input_ids)
    
    print(images_tensor.shape)
    temperature = 0.2
    num_beams = 1
    top_p = 0.95
    max_new_tokens = max_new_tokens
    with torch.inference_mode():
        output_ids = model.generate(
            input_ids,
            images=[
                images_tensor,
            ],
            do_sample=True if temperature > 0 else False,
            temperature=temperature,
            top_p=top_p,
            num_beams=num_beams,
            max_new_tokens=max_new_tokens,
            use_cache=True,
            stopping_criteria=[stopping_criteria],
        )
    
    outputs = tokenizer.batch_decode(output_ids, skip_special_tokens=True)[0]
    outputs = outputs.strip()
    print(outputs)
    if outputs.endswith(stop_str):
        outputs = outputs[: -len(stop_str)]
    outputs = outputs.strip()
    # print(outputs)
    return outputs

# %%
model_name
# Out:
# 'VILA1.5-13b'

# %%
if "llama-2" in model_name.lower():
    conv_mode = "llava_llama_2"
elif "v1" in model_name.lower():
    conv_mode = "llava_v1"
elif "mpt" in model_name.lower():
    conv_mode = "mpt"
else:
    conv_mode = "llava_v0"
print(conv_mode)
# Out:
# llava_v0

# %%
n = 8
use_random = True
n_random = 0

# %%
for n in [0,2,4,6,8]:
    print(n)
    out_data = {
        "outputs": []
    }
    model_name = model_name_or_path.split("/")[-1]
    save_path = f"/home/asureddy_umass_edu/cs682/VILA/results/captioning/{model_name}_{n}-shot"
    if use_random:
        save_path += "_random-examples"
    if n_random:
        save_path += f"{n_random}_random-examples"
    save_path += ".json"
    # print(args)
    # doing for a max of 10k examples
    for i in tqdm(range(min(100, len(val_dataset)))):
        out = get_output(val_dataset[i],n,use_random, n_random)
        out_data["outputs"].append(out)
    
    with open(save_path,'w') as f:
        json.dump(out_data, f)
# Out:
# 0
#   1%|█▋                                                                                                                                                                     | 1/100 [00:00<01:23,  1.19it/s]
# query:  Caption:
# caption: A man in a white apron stands in a kitchen filled with various cooking utensils and
#   2%|███▎                                                                                                                                                                   | 2/100 [00:01<01:05,  1.50it/s]
# query:  Caption:
# caption: A kitchen with a bowl of fruit on the table.
#   3%|█████                                                                                                                                                                  | 3/100 [00:02<01:10,  1.37it/s]
# query:  Caption:
# caption: A man stands on a sidewalk next to a shopping cart full of items, while a woman
#   4%|██████▋                                                                                                                                                                | 4/100 [00:03<01:13,  1.31it/s]
# query:  Caption:
# caption: Two young men are performing tricks at a skatepark. One is on a skateboard
#   5%|████████▎                                                                                                                                                              | 5/100 [00:03<01:11,  1.33it/s]
# query:  Caption:
# caption: A blue bicycle is parked on the sidewalk next to a street.
#   6%|██████████                                                                                                                                                             | 6/100 [00:04<01:12,  1.29it/s]
# query:  Caption:
# caption: A bathroom with a white toilet and sink, a white shower curtain, and
#   7%|███████████▋                                                                                                                                                           | 7/100 [00:05<01:12,  1.28it/s]
# query:  Caption:
# caption: A bathroom with a white toilet and a white sink. There is a white shower
#   8%|█████████████▎                                                                                                                                                         | 8/100 [00:05<01:06,  1.39it/s]
# query:  Caption:
# caption: A black and red motorcycle is on display at a convention.
#   9%|███████████████                                                                                                                                                        | 9/100 [00:06<01:02,  1.46it/s]
# query:  Caption:
# caption: A row of old toilets lined up in a yard.
#  10%|████████████████▌                                                                                                                                                     | 10/100 [00:07<01:05,  1.38it/s]
# query:  Caption:
# caption: A beige toilet with a bidet attachment and a control panel on the side.
#  11%|██████████████████▎                                                                                                                                                   | 11/100 [00:07<00:59,  1.50it/s]
# query:  Caption:
# caption: A busy street in India with motorcycles and cars.
#  12%|███████████████████▉                                                                                                                                                  | 12/100 [00:08<01:02,  1.40it/s]
# query:  Caption:
# caption: A woman is sitting at a desk in a cluttered office, typing on a computer.
#  13%|█████████████████████▌                                                                                                                                                | 13/100 [00:09<01:03,  1.37it/s]
# query:  Caption:
# caption: An old doorway with a blue door and two vases of flowers on either side.
#  14%|███████████████████████▏                                                                                                                                              | 14/100 [00:10<01:03,  1.36it/s]
# query:  Caption:
# caption: A living room with a white chair, a TV, and a bookshelf.
#  15%|████████████████████████▉                                                                                                                                             | 15/100 [00:11<01:04,  1.31it/s]
# query:  Caption:
# caption: A painting of a still life scene, featuring a copper pitcher, a candlestick
#  16%|██████████████████████████▌                                                                                                                                           | 16/100 [00:11<01:05,  1.28it/s]
# query:  Caption:
# caption: A large white airplane is parked at an airport gate, with a jet bridge attached to
#  17%|████████████████████████████▏                                                                                                                                         | 17/100 [00:12<01:04,  1.29it/s]
# query:  Caption:
# caption: A toy giraffe, cow, and deer are displayed on a table.
#  18%|█████████████████████████████▉                                                                                                                                        | 18/100 [00:13<01:04,  1.27it/s]
# query:  Caption:
# caption: A wooden bench overlooking a beach with boats in the water and an island in the distance.
#  19%|███████████████████████████████▌                                                                                                                                      | 19/100 [00:14<01:04,  1.25it/s]
# query:  Caption:
# caption: A man in a green shirt and hat herds a large group of goats in a desert
#  20%|█████████████████████████████████▏                                                                                                                                    | 20/100 [00:14<00:57,  1.38it/s]
# query:  Caption:
# caption: A busy street in a city with cars and a bus.
#  21%|██████████████████████████████████▊                                                                                                                                   | 21/100 [00:15<00:59,  1.33it/s]
# query:  Caption:
# caption: A blue bus with the words "Scott Brown, He's for us" on the side
#  22%|████████████████████████████████████▌                                                                                                                                 | 22/100 [00:16<01:00,  1.30it/s]
# query:  Caption:
# caption: A yellow bus with the number 10 on the front is driving down a street. There are
#  23%|██████████████████████████████████████▏                                                                                                                               | 23/100 [00:17<00:58,  1.31it/s]
# query:  Caption:
# caption: Two people are crossing the street in front of a blue bus and a white bus.
#  24%|███████████████████████████████████████▊                                                                                                                              | 24/100 [00:18<00:59,  1.27it/s]
# query:  Caption:
# caption: A white bus with red and orange stripes on the top is driving down a busy highway.
#  25%|█████████████████████████████████████████▌                                                                                                                            | 25/100 [00:18<01:00,  1.25it/s]
# query:  Caption:
# caption: Two orange signs on a green pole, with a lion statue on them, are in front of
#  26%|███████████████████████████████████████████▏                                                                                                                          | 26/100 [00:19<00:59,  1.24it/s]
# query:  Caption:
# caption: A sign that says "No Bicycles, Skates or Skateboards on Sidewalks
#  27%|████████████████████████████████████████████▊                                                                                                                         | 27/100 [00:20<00:56,  1.29it/s]
# query:  Caption:
# caption: A mother giraffe and her baby stand in front of a wooden wall.
#  28%|██████████████████████████████████████████████▍                                                                                                                       | 28/100 [00:21<00:55,  1.30it/s]
# query:  Caption:
# caption: A woman sits on a train with a cane and a plastic bag.
#  29%|████████████████████████████████████████████████▏                                                                                                                     | 29/100 [00:21<00:55,  1.28it/s]
# query:  Caption:
# caption: A woman sits on a bench in front of the Eiffel Tower, surrounded by p
#  30%|█████████████████████████████████████████████████▊                                                                                                                    | 30/100 [00:22<00:49,  1.41it/s]
# query:  Caption:
# caption: A street sign for parking and the name Gladys.
#  31%|███████████████████████████████████████████████████▍                                                                                                                  | 31/100 [00:23<00:48,  1.42it/s]
# query:  Caption:
# caption: Three guinea fowl are walking on a dry grassy hillside.
#  32%|█████████████████████████████████████████████████████                                                                                                                 | 32/100 [00:23<00:42,  1.58it/s]
# query:  Caption:
# caption: A blue and white train is approaching a station.
#  33%|██████████████████████████████████████████████████████▊                                                                                                               | 33/100 [00:24<00:45,  1.46it/s]
# query:  Caption:
# caption: A blue train car with a person hanging out of the door is traveling on a track.
#  34%|████████████████████████████████████████████████████████▍                                                                                                             | 34/100 [00:25<00:43,  1.52it/s]
# query:  Caption:
# caption: A red stop sign is leaning against a beige wall.
#  35%|██████████████████████████████████████████████████████████                                                                                                            | 35/100 [00:25<00:44,  1.44it/s]
# query:  Caption:
# caption: A red stop sign is attached to a wooden pole that is leaning to the side.
#  36%|███████████████████████████████████████████████████████████▊                                                                                                          | 36/100 [00:26<00:46,  1.37it/s]
# query:  Caption:
# caption: A stop sign with the word "Voldemort" written underneath it in white.
#  37%|█████████████████████████████████████████████████████████████▍                                                                                                        | 37/100 [00:27<00:43,  1.46it/s]
# query:  Caption:
# caption: A dog and a cat laying on a couch together.
#  38%|███████████████████████████████████████████████████████████████                                                                                                       | 38/100 [00:28<00:44,  1.38it/s]
# query:  Caption:
# caption: Two cats, one orange and one brown, sitting on a concrete surface next to a pair of
#  39%|████████████████████████████████████████████████████████████████▋                                                                                                     | 39/100 [00:28<00:44,  1.37it/s]
# query:  Caption:
# caption: An orange and white cat is sitting in an open suitcase, surrounded by clothes.
#  40%|██████████████████████████████████████████████████████████████████▍                                                                                                   | 40/100 [00:29<00:44,  1.34it/s]
# query:  Caption:
# caption: A herd of cows grazing in a field with a forest in the background.
#  41%|████████████████████████████████████████████████████████████████████                                                                                                  | 41/100 [00:30<00:41,  1.44it/s]
# query:  Caption:
# caption: Two cows in a field with a temple in the background.
#  42%|█████████████████████████████████████████████████████████████████████▋                                                                                                | 42/100 [00:30<00:40,  1.44it/s]
# query:  Caption:
# caption: A cat is standing on a wooden TV stand, looking at the TV screen.
#  43%|███████████████████████████████████████████████████████████████████████▍                                                                                              | 43/100 [00:31<00:39,  1.44it/s]
# query:  Caption:
# caption: A cat wearing a collar is sitting in front of a computer monitor.
#  44%|█████████████████████████████████████████████████████████████████████████                                                                                             | 44/100 [00:32<00:40,  1.37it/s]
# query:  Caption:
# caption: A young woman with red hair and piercings on her face and nose is wearing a white
#  45%|██████████████████████████████████████████████████████████████████████████▋                                                                                           | 45/100 [00:33<00:39,  1.38it/s]
# query:  Caption:
# caption: A group of people are gathered around a man who is holding a white cloth.
#  46%|████████████████████████████████████████████████████████████████████████████▎                                                                                         | 46/100 [00:33<00:40,  1.33it/s]
# query:  Caption:
# caption: A large boat is docked at a rocky shore, with people on the deck and in the
#  47%|██████████████████████████████████████████████████████████████████████████████                                                                                        | 47/100 [00:34<00:40,  1.30it/s]
# query:  Caption:
# caption: A herd of elephants are grazing in a field with trees in the background.
#  48%|███████████████████████████████████████████████████████████████████████████████▋                                                                                      | 48/100 [00:35<00:41,  1.26it/s]
# query:  Caption:
# caption: A large white boat with orange and blue accents is sailing on a dark, choppy river
#  49%|█████████████████████████████████████████████████████████████████████████████████▎                                                                                    | 49/100 [00:36<00:40,  1.25it/s]
# query:  Caption:
# caption: A large elephant stands in a dry grassy area with trees and rocks in the background.
#  50%|███████████████████████████████████████████████████████████████████████████████████                                                                                   | 50/100 [00:37<00:40,  1.24it/s]
# query:  Caption:
# caption: A group of people walk down a busy street in London, with one person holding a Union Jack um
#  51%|████████████████████████████████████████████████████████████████████████████████████▋                                                                                 | 51/100 [00:37<00:39,  1.24it/s]
# query:  Caption:
# caption: A large elephant with tusks is standing in a grassy area with trees in the
#  52%|██████████████████████████████████████████████████████████████████████████████████████▎                                                                               | 52/100 [00:38<00:39,  1.23it/s]
# query:  Caption:
# caption: Three women are walking together under an umbrella, laughing and enjoying each other's
#  53%|███████████████████████████████████████████████████████████████████████████████████████▉                                                                              | 53/100 [00:39<00:38,  1.22it/s]
# query:  Caption:
# caption: A black briefcase with various stickers on it, including one that says "No Ving As
#  54%|█████████████████████████████████████████████████████████████████████████████████████████▋                                                                            | 54/100 [00:40<00:37,  1.23it/s]
# query:  Caption:
# caption: A man in an orange shirt is playing frisbee with his dog in a park.
#  55%|███████████████████████████████████████████████████████████████████████████████████████████▎                                                                          | 55/100 [00:41<00:36,  1.23it/s]
# query:  Caption:
# caption: A young man stands on a train platform with several bags of luggage around him.
#  56%|████████████████████████████████████████████████████████████████████████████████████████████▉                                                                         | 56/100 [00:42<00:35,  1.24it/s]
# query:  Caption:
# caption: A polar bear stands on the edge of a pond as a bird flies in front of it
#  57%|██████████████████████████████████████████████████████████████████████████████████████████████▌                                                                       | 57/100 [00:42<00:34,  1.24it/s]
# query:  Caption:
# caption: A lone zebra stands in a field of tall green grass, its black and white stri
#  58%|████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                     | 58/100 [00:43<00:33,  1.24it/s]
# query:  Caption:
# caption: Two zebras and a wildebeest graze in a grassy field with a body
#  59%|█████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                    | 59/100 [00:44<00:33,  1.23it/s]
# query:  Caption:
# caption: A zebra stands in a field, its black and white stripes contrasting with the green
#  60%|███████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                  | 60/100 [00:45<00:32,  1.23it/s]
# query:  Caption:
# caption: Two zebras are fighting in a field of dry grass, kicking up a cloud of dust
#  61%|█████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                | 61/100 [00:45<00:29,  1.32it/s]
# query:  Caption:
# caption: A group of jockeys race their horses on a beach.
#  62%|██████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                               | 62/100 [00:46<00:26,  1.42it/s]
# query:  Caption:
# caption: A white horse pulling a trolley car down a street.
#  63%|████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                             | 63/100 [00:47<00:25,  1.42it/s]
# query:  Caption:
# caption: A white horse with a blonde mane stands in a fenced area.
#  64%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                           | 64/100 [00:47<00:25,  1.41it/s]
# query:  Caption:
# caption: A man in a blue jacket is cross-country skiing in the snow.
#  65%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                          | 65/100 [00:48<00:21,  1.61it/s]
# query:  Caption:
# caption: A baseball player is throwing a ball.
#  66%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                        | 66/100 [00:49<00:23,  1.47it/s]
# query:  Caption:
# caption: A person in a blue jacket and red pants is snowboarding down a snowy hill
#  67%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                      | 67/100 [00:49<00:23,  1.40it/s]
# query:  Caption:
# caption: A blue plate of dessert with marshmallows, chocolate, and sprink
#  68%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                     | 68/100 [00:50<00:23,  1.35it/s]
# query:  Caption:
# caption: A black plate filled with a delicious stir fry of noodles, broccoli,
#  69%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                   | 69/100 [00:51<00:22,  1.38it/s]
# query:  Caption:
# caption: A man in a yellow and black suit is riding a skateboard.
#  70%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                 | 70/100 [00:52<00:22,  1.34it/s]
# query:  Caption:
# caption: A young boy is performing a skateboard trick on a ramp at a skatepark.
#  71%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                | 71/100 [00:52<00:20,  1.42it/s]
# query:  Caption:
# caption: A young man is skateboarding at a skate park.
#  72%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                              | 72/100 [00:53<00:20,  1.36it/s]
# query:  Caption:
# caption: A man in a blue shirt is performing a skateboard trick in mid-air at a
#  73%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                            | 73/100 [00:54<00:20,  1.32it/s]
# query:  Caption:
# caption: A man in an AC/DC shirt is holding a skateboard and a microphone.
#  74%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                           | 74/100 [00:55<00:18,  1.38it/s]
# query:  Caption:
# caption: A person is sitting on the floor next to a plate of donuts.
#  75%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                         | 75/100 [00:55<00:18,  1.33it/s]
# query:  Caption:
# caption: A man wearing glasses is taking a bite out of a glazed donut.
#  76%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                       | 76/100 [00:56<00:17,  1.41it/s]
# query:  Caption:
# caption: Three donuts on a plate with a coffee pot in the background.
#  77%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                      | 77/100 [00:57<00:17,  1.35it/s]
# query:  Caption:
# caption: Three women in red, yellow, and blue shirts stand in front of a bakery
#  78%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                    | 78/100 [00:58<00:16,  1.35it/s]
# query:  Caption:
# caption: A black and white photo of a tray of freshly baked donuts.
#  79%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                  | 79/100 [00:58<00:14,  1.42it/s]
# query:  Caption:
# caption: A plate of sandwiches with salmon and avocado.
#  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                 | 80/100 [00:59<00:14,  1.36it/s]
# query:  Caption:
# caption: A man is holding a chocolate covered donut with white icing in the shape of an
#  81%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                               | 81/100 [01:00<00:12,  1.51it/s]
# query:  Caption:
# caption: A man is throwing a ball on a tennis court.
#  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                              | 82/100 [01:00<00:12,  1.42it/s]
# query:  Caption:
# caption: A group of surfers stand on the beach at sunset, holding their surfboards.
#  83%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                            | 83/100 [01:01<00:12,  1.37it/s]
# query:  Caption:
# caption: A beautifully decorated wedding cake sits on a table, surrounded by candles and
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                          | 84/100 [01:02<00:11,  1.43it/s]
# query:  Caption:
# caption: A group of men are playing soccer on a grassy field.
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                         | 85/100 [01:03<00:10,  1.37it/s]
# query:  Caption:
# caption: A woman is holding a birthday cake with lit candles, while another woman is pointing at
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                       | 86/100 [01:03<00:09,  1.44it/s]
# query:  Caption:
# caption: A hospital room with a bed and a window with curtains.
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                     | 87/100 [01:04<00:09,  1.42it/s]
# query:  Caption:
# caption: A messy bedroom with a bed, boxes, and other items scattered around.
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                    | 88/100 [01:05<00:08,  1.43it/s]
# query:  Caption:
# caption: A young child is sitting at a table eating a piece of cake.
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                  | 89/100 [01:05<00:07,  1.48it/s]
# query:  Caption:
# caption: A group of children are playing soccer on a grassy field.
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                | 90/100 [01:06<00:06,  1.58it/s]
# query:  Caption:
# caption: A bed with a white canopy and white pillows.
#  91%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████               | 91/100 [01:07<00:08,  1.10it/s]
# query:  Caption:
# caption: A woman is lying in a hospital bed, hooked up to medical equipment.
#  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋             | 92/100 [01:10<00:10,  1.35s/it]
# query:  Caption:
# caption: A homemade pizza with a variety of toppings sits on a wooden cutting board on
#  93%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍           | 93/100 [01:12<00:11,  1.66s/it]
# query:  Caption:
# caption: A man in a black wetsuit is paddling on a white surfboard in the
#  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████          | 94/100 [01:13<00:09,  1.59s/it]
# query:  Caption:
# caption: A young boy is sleeping on a bed with a floral patterned blanket.
#  95%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋        | 95/100 [01:14<00:06,  1.30s/it]
# query:  Caption:
# caption: A picture of a bride and groom sitting on a bed.
#  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎      | 96/100 [01:15<00:04,  1.15s/it]
# query:  Caption:
# caption: A man in a white lab coat stands in front of a pink bus with a window, interview
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████     | 97/100 [01:15<00:02,  1.04it/s]
# query:  Caption:
# caption: A young girl is enjoying a slice of pizza.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 98/100 [01:16<00:01,  1.09it/s]
# query:  Caption:
# caption: A black and white photo of a living room with a chair, a mirror, and a plant.
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎ | 99/100 [01:17<00:00,  1.13it/s]
# query:  Caption:
# caption: A slice of pizza with sauce and cheese on it, sitting on a white paper plate
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:18<00:00,  1.28it/s]
# query:  Caption:
# caption: A tennis player is swinging his racket at a ball on a tennis court.
# 2
#   1%|█▋                                                                                                                                                                     | 1/100 [00:00<00:52,  1.89it/s]
# query:   Caption: People hanging out in a kitchen eating and drinking    Caption: A person with an umbrella on a rainy street.  Caption:
# caption: A person cooking in a kitchen.
#   2%|███▎                                                                                                                                                                   | 2/100 [00:01<01:02,  1.56it/s]
# query:   Caption: A woman holding up toothbrushes in a  store.   Caption: Dozens of colorful kites flying above a crowd of people.  Caption:
# caption: A kitchen with a bowl of oranges on the table.
#   3%|█████                                                                                                                                                                  | 3/100 [00:02<01:13,  1.33it/s]
# query:   Caption: Two giraffes that are standing in the grass.   Caption: Two horses grazing on grass in the mountains.  Caption:
# caption: A man is standing on the sidewalk with a shopping cart full of items.
#   4%|██████▋                                                                                                                                                                | 4/100 [00:02<01:11,  1.35it/s]
# query:   Caption: A man sitting down holding a piece of red luggage.   Caption: Assortment of meats with sauce and vegetables displayed.  Caption:
# caption: Two people are skateboarding in a skate park.
#   5%|████████▎                                                                                                                                                              | 5/100 [00:03<01:08,  1.39it/s]
# query:   Caption: A dog sitting in a white bath tub near shampoo and conditioner.   Caption: A bear ke leaning up against a wooden building.  Caption:
# caption: A blue bicycle parked on a sidewalk.
#   6%|██████████                                                                                                                                                             | 6/100 [00:04<01:09,  1.34it/s]
# query:   Caption: A man standing next to a woman while holding a toothbrush.   Caption: A cake made to look like a hot dog and a ketchup bottle.  Caption:
# caption: A bathroom with a toilet, sink, and shower.
#   7%|███████████▋                                                                                                                                                           | 7/100 [00:04<01:04,  1.44it/s]
# query:   Caption: A cat sitting on a desk in front of a cat picture.   Caption: Tennis players do give congratulations to their opponents.  Caption:
# caption: A bathroom with a hole in the floor.
#   8%|█████████████▎                                                                                                                                                         | 8/100 [00:05<01:00,  1.53it/s]
# query:   Caption: Four body boards are stuck upright in the sand as a woman walks two dogs on the beach.    Caption: A herd of animals standing on top of a grass covered hillside.  Caption:
# caption: A motorcycle on display at a convention.
#   9%|███████████████                                                                                                                                                        | 9/100 [00:06<01:03,  1.44it/s]
# query:   Caption: A white and pink kite flying through a blue cloud filled sky.   Caption: two girls are riding a skateboard down the street.  Caption:
# caption: A row of old toilets are lined up in a field.
#  10%|████████████████▌                                                                                                                                                     | 10/100 [00:06<00:59,  1.51it/s]
# query:   Caption: A picture of two people and an umbrella.   Caption: A young woman using a Wii controller playing a game and laughing.  Caption:
# caption: A toilet with a bidet attachment.
#  11%|██████████████████▎                                                                                                                                                   | 11/100 [00:07<01:02,  1.43it/s]
# query:   Caption: a group of people walking around a building with a mountain in the background   Caption: A group of muddy elephants standing by rocks.  Caption:
# caption: A busy street in India with motorcycles and pedestrians.
#  12%|███████████████████▉                                                                                                                                                  | 12/100 [00:08<00:57,  1.52it/s]
# query:   Caption: A car seat covered in a piece of cake and frosting.   Caption: Boy on a skateboard in a skateboard park.   Caption:
# caption: A woman sitting at a computer desk.
#  13%|█████████████████████▌                                                                                                                                                | 13/100 [00:09<01:02,  1.39it/s]
# query:   Caption: A broken toilet in a dirty bathroom.    Caption: a close up of a bunch of bananas in a bowl  Caption:
# caption: A doorway to an old building with a sign that says "Escalita"
#  14%|███████████████████████▏                                                                                                                                              | 14/100 [00:09<01:04,  1.34it/s]
# query:   Caption: these three small children are playing outside in the grass   Caption: Many people are seen walking on a cement road.  Caption:
# caption: A living room with a chair, a television, and a bookshelf.
#  15%|████████████████████████▉                                                                                                                                             | 15/100 [00:10<01:03,  1.34it/s]
# query:   Caption: A white toilet sitting in a room near a doorway.   Caption: Black and white photograph of women walking towards an umbrella.  Caption:
# caption: A painting of a pitcher, candle, and oranges.
#  16%|██████████████████████████▌                                                                                                                                           | 16/100 [00:11<01:04,  1.29it/s]
# query:   Caption: A man with a suit and sunglasses leans on a railing.    Caption: a guy that is on a surfboard flying in the sky  Caption:
# caption: a man in a suit and sunglasses leans on a railing
#  17%|████████████████████████████▏                                                                                                                                         | 17/100 [00:12<01:07,  1.22it/s]
# query:   Caption: A professional tennis match and a black player returning the ball   Caption: A bunch of people on a beach with a pretty kite.  Caption:
# caption: A bunch of toy animals, including a giraffe, cow, and deer, are
#  18%|█████████████████████████████▉                                                                                                                                        | 18/100 [00:12<01:01,  1.34it/s]
# query:   Caption: A man and young boy with tennis rackets on a blue tennis court.   Caption: Meat and pasta dish with vegetable served in bowl.  Caption:
# caption: A bench overlooking a body of water.
#  19%|███████████████████████████████▌                                                                                                                                      | 19/100 [00:13<00:58,  1.38it/s]
# query:   Caption: A woman with a cup of coffee and a donut smiling.   Caption: The men are all ready to surf on the water  Caption:
# caption: A man is herding a large group of goats.
#  20%|█████████████████████████████████▏                                                                                                                                    | 20/100 [00:14<00:57,  1.40it/s]
# query:   Caption: A car stopped at a traffic light with it's brake lights on.   Caption: A series of little weird cars in fron of an european arch.  Caption:
# caption: A busy street in a city with cars and buses.
#  21%|██████████████████████████████████▊                                                                                                                                   | 21/100 [00:14<00:53,  1.47it/s]
# query:   Caption: A pork sandwich on a roll with slaw on a plate with a glass of beer behind.   Caption: a number of kites in the sky with a kite on the ground  Caption:
# caption: A bus with the words Scott Brown on it.
#  22%|████████████████████████████████████▌                                                                                                                                 | 22/100 [00:15<00:55,  1.41it/s]
# query:   Caption: A red stop sign that says "PARE" near a brick intersection.    Caption: A woman standing next to C3PO near an oven.  Caption:
# caption: A yellow bus on a city street with people walking on the sidewalk.
#  23%|██████████████████████████████████████▏                                                                                                                               | 23/100 [00:16<00:51,  1.50it/s]
# query:   Caption: A man holding a child close to the fence of a giraffe's enclosure.    Caption: A man in green pants suspenders and a white shirt.  Caption:
# caption: A busy street with cars and buses.
#  24%|███████████████████████████████████████▊                                                                                                                              | 24/100 [00:16<00:47,  1.60it/s]
# query:   Caption: A kitchen that appears to be missing a cabinet door.   Caption: A fighter jet taking off from an airport runway.  Caption:
# caption: A city bus driving down a highway.
#  25%|█████████████████████████████████████████▌                                                                                                                            | 25/100 [00:17<00:48,  1.53it/s]
# query:   Caption: A man wears a black vest, a black hat, and a mustache.   Caption: A group of people around a table with boxes of pizza eating.  Caption:
# caption: A sign with a lion on it is on a pole.
#  26%|███████████████████████████████████████████▏                                                                                                                          | 26/100 [00:18<00:54,  1.35it/s]
# query:   Caption: A man holding up a surfboard that reads "Stage 3 Winner".   Caption: Man on a skateboard wearing helmet and knee pads safety gear.  Caption:
# caption: A sign prohibiting bicycles, skateboards, or skateboards on sidewalks
#  27%|████████████████████████████████████████████▊                                                                                                                         | 27/100 [00:19<00:58,  1.25it/s]
# query:   Caption: a little boy is holding up a cell phone   Caption: A zebra walking past a stone structure near a forest.  Caption:
# caption: A mother giraffe and her baby giraffe standing in front of a wooden structure.
#  28%|██████████████████████████████████████████████▍                                                                                                                       | 28/100 [00:20<00:56,  1.28it/s]
# query:   Caption: A wooden table topped with a microwave and a toaster.   Caption: Two people are playing a game of tennis.  Caption:
# caption: A woman is sitting on a train with a bag next to her.
#  29%|████████████████████████████████████████████████▏                                                                                                                     | 29/100 [00:20<00:55,  1.27it/s]
# query:   Caption: an advertisement of an old cell phone    Caption: A white bed in a bedroom next to a doorway.  Caption:
# caption: A woman sits on a bench with pigeons around her.
#  30%|█████████████████████████████████████████████████▊                                                                                                                    | 30/100 [00:21<00:51,  1.36it/s]
# query:   Caption: a cat paw sticking out from underneath a black plastic bag next to a pair of blue handled scissors.   Caption: An imposing building rises in the distance on a rainy day.  Caption:
# caption: A street sign for Parking and Gladys.
#  31%|███████████████████████████████████████████████████▍                                                                                                                  | 31/100 [00:22<00:51,  1.34it/s]
# query:   Caption: Batman costume and other older toys on a vendor shelf.   Caption: A train traveling through a lush green park.  Caption:
# caption: Three guinea fowl walking on a dry grassy field.
#  32%|█████████████████████████████████████████████████████                                                                                                                 | 32/100 [00:22<00:48,  1.41it/s]
# query:   Caption: A group of people sitting on a white boat floating on a lake.   Caption: A group of skiers trekking through the deep snow  Caption:
# caption: A blue and white train is pulling into a station.
#  33%|██████████████████████████████████████████████████████▊                                                                                                               | 33/100 [00:23<00:42,  1.56it/s]
# query:   Caption: A man holding a Nintendo Wii controller next to a pretty young girl holding another Nintendo Wii controller.   Caption: a couple of men are playing baseball in a field  Caption:
# caption: A blue train on the tracks.
#  34%|████████████████████████████████████████████████████████▍                                                                                                             | 34/100 [00:23<00:39,  1.68it/s]
# query:   Caption: A couple of giraffe standing around a tree.   Caption: a toddler standing while holding onto a toilet and reaching for a towel  Caption:
# caption: A stop sign on a wall.
#  35%|██████████████████████████████████████████████████████████                                                                                                            | 35/100 [00:24<00:44,  1.46it/s]
# query:   Caption: A man leaning on a counter in front of a cake with candles on it.    Caption: A man riding on a subway train holding a jacket.  Caption:
# caption: A stop sign that has been knocked over and is leaning against a wooden pole.
#  36%|███████████████████████████████████████████████████████████▊                                                                                                          | 36/100 [00:25<00:47,  1.35it/s]
# query:   Caption: I am unable to see the image above.   Caption: A forest filled with trees and a couple of horses.  Caption:
# caption: A stop sign with the word "voldemort" written underneath it.
#  37%|█████████████████████████████████████████████████████████████▍                                                                                                        | 37/100 [00:26<00:45,  1.38it/s]
# query:   Caption: A banana tree filled with lots of unripe bananas.   Caption: A chalk board covered in words and lettering.  Caption:
# caption: A dog and a cat laying on a couch.
#  38%|███████████████████████████████████████████████████████████████                                                                                                       | 38/100 [00:27<00:46,  1.34it/s]
# query:   Caption: The book is laying open on the bed.   Caption: Plane getting ready for takeoff on the runway at airport.  Caption:
# caption: Two cats laying on a step with a shoe between them.
#  39%|████████████████████████████████████████████████████████████████▋                                                                                                     | 39/100 [00:27<00:42,  1.43it/s]
# query:   Caption: People standing on the sidewalk, with some holding luggage.    Caption: A stack of luggage is shown sitting on a rolling cart.  Caption:
# caption: A cat is sitting in a suitcase.
#  40%|██████████████████████████████████████████████████████████████████▍                                                                                                   | 40/100 [00:28<00:42,  1.42it/s]
# query:   Caption: A man is repairs a traffic light from a crane on top of a truck and a car next to it   Caption: A blue piece of luggage sitting on top of a wooden chair.  Caption:
# caption: A pastoral scene with cows grazing in a field.
#  41%|████████████████████████████████████████████████████████████████████                                                                                                  | 41/100 [00:29<00:43,  1.36it/s]
# query:   Caption: A silver motorcycle parked on the side of a street.   Caption: Two people holding umbrellas standing at the edge of a high cliff overlooking a lake.  Caption:
# caption: A white cow standing in a field with a pagoda in the background.
#  42%|█████████████████████████████████████████████████████████████████████▋                                                                                                | 42/100 [00:30<00:43,  1.33it/s]
# query:   Caption: A group of young children playing with a soccer ball.   Caption: A tall yellow double decker bus parked next to another bus.  Caption:
# caption: A cat is standing on a tv stand in front of a tv.
#  43%|███████████████████████████████████████████████████████████████████████▍                                                                                              | 43/100 [00:30<00:40,  1.41it/s]
# query:   Caption: A ceramic coffee cup inside of a silver microwave oven.   Caption: Two tennis players are talking over the tennis net.  Caption:
# caption: A cat is looking up at a laptop screen.
#  44%|█████████████████████████████████████████████████████████████████████████                                                                                             | 44/100 [00:31<00:41,  1.36it/s]
# ...
# caption: A person holding a chocolate donut with white icing.
#  81%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                               | 81/100 [01:25<00:18,  1.05it/s]
# query:   Caption: A hummingbird sitting on a plant preparing to flap its wings.   Caption: A person riding a snowboard down a snow covered slople   Caption: A room filled with clutter and a laptop computer.   Caption: A sign mounted to a pole that reads bus stop.   Caption: Several street signs in Spanish are shown with a brick background.   Caption: A white cat laying on a blue and white bed.   Caption: A group of ducks floating on top of a lake.   Caption: Boats riding in the river in opposite directions  Caption:
# caption: A man playing tennis.
#  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                              | 82/100 [01:27<00:18,  1.05s/it]
# query:   Caption: a narrow fridge sitting next to a big window    Caption: A yellow teddy bear on a little girls bed   Caption: A blue and white bus on street next to a building.   Caption: People stand on the beach, and take a photo and sit on a surf board.   Caption: A single cow that is walking in a parking lot.   Caption: A fancy bathroom with a large tub, separate shower, and double sink.   Caption: A man riding a bicycle down a sidewalk.   Caption: A man walking down a street next to a tall building.  Caption:
# caption: People are standing on the beach, and a surfer is carrying a surfboard.
#  83%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                            | 83/100 [01:28<00:18,  1.12s/it]
# query:   Caption: A man standing next to a bag of luggage.   Caption: A large bunch of green bananas hanging from a tree.   Caption: A group of flight attendants taking a break together.    Caption: a girl playing tennis hits the ball back to the opponet   Caption: A cat standing on top of a book shelf filled with books.   Caption: A birthday cake with candles in it sitting on a table.    Caption: A brown and white bird on a branch with sky in the background.   Caption: A man on the tennis court is hitting the ball with his racquet.  Caption:
# caption: A two tiered white cake with blue ribbons and flowers on it.
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                          | 84/100 [01:29<00:16,  1.06s/it]
# query:   Caption: some horses are running and a man is riding in front   Caption: Two trains that are on the rails near a station.   Caption: An empty church with wooden benches and a cross.   Caption: A white aeroplane is flying inside a room   Caption: a black and white image of men with a horse   Caption: A castle with a large clock hanging from it's side.   Caption: there is a large bird standing on the side of a walkway    Caption: A white dog having its hair blown dry by a man.  Caption:
# caption: A group of men are playing soccer.
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                         | 85/100 [01:30<00:16,  1.07s/it]
# query:   Caption: A TV inside of a bathroom mirror next to a light.   Caption: A cat sits on the lid of a toilet.   Caption: A plane is somewhat distant away from the green grass.    Caption: There is an empty cup of coffee next to a laptop and open book at a cafe.    Caption: A banana peel that is on a tile floor.    Caption: A woman holding a glass of wine has her picture taken.   Caption: People standing in line to check in at an airport.   Caption: A couple of women sitting down together eating food.  Caption:
# caption: A woman is holding a cake with candles on it.
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                       | 86/100 [01:31<00:14,  1.04s/it]
# query:   Caption: A man and woman are playing Wii sitting on a couch.   Caption: a cut in half sandwich sitting on top of a white plate.   Caption: Decorative containers and vases sit on a table.   Caption: A Seattle Mariner's baseball player is up to bat at a baseball park.   Caption: a male bicycle rider in a black shirt some cars and buildings   Caption: A skateboarder is riding an obstacle in a skate park.    Caption: A bus on the street at night with lights shining every where    Caption: A bus is parked at the bus station.  Caption:
# caption: A hospital room with a bed and medical equipment.
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                     | 87/100 [01:32<00:13,  1.05s/it]
# query:   Caption: A store shelf filled with different heart shaped boxes.   Caption: A couple of computer desk with computers on top of them.   Caption: A bus driving down a city street at night.   Caption: some children are in a yard and one has a dog on a leash   Caption: A  busy chinese market crowded at night.   Caption: An old photograph shows a picture of a tennis team.    Caption: Various plates of food that include pastries and broccoli.   Caption: A boy wearing a white dress shirt and sweater with shorts  Caption:
# caption: A bedroom with a bed, a chair, and boxes.
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                    | 88/100 [01:33<00:12,  1.05s/it]
# query:   Caption: A tennis player throws the ball to prepare to hit it.   Caption: A baseball player is attempting to hit the ball.    Caption: This is a glass of orange juice and a sandwich on a red tray.   Caption: A tall, stone clock tower rises above green trees   Caption: A couple of people on a bike on a road.   Caption: A city bus is waiting at the bus stop.   Caption: An unfinished bathroom with a toilet is being worked on.   Caption: A large green and red bird eating a ripe banana.  Caption:
# caption: A young child is eating a piece of cake.
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                  | 89/100 [01:34<00:11,  1.01s/it]
# query:   Caption: A photo of a man on a skateboard.   Caption: Two chairs sitting in a living room under a framed picture.   Caption: a man about to hit a base ball in a game   Caption: a cat sits next to a remote control    Caption: there is a small yogurt next to a small lap top   Caption: A woman is in a bedroom holding a wine glass.   Caption: An older woman holding a Nintendo Wii game controller.   Caption: Three adults and three children in ski attire on top of a snow covered mountain.  Caption:
# caption: A group of children playing soccer.
#  90%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                | 90/100 [01:35<00:09,  1.02it/s]
# query:   Caption: A painted hanging building sign for a restaurant.   Caption: A vintage photo from the 1950's of a small town street lined with parked cars.   Caption: A group of giraffes standing together inside a fenced area.   Caption: A street light sitting next to a building on the side of a road.   Caption: A young man sitting on a park bench looking out at a field   Caption: There is a man guiding a horse along the beach.   Caption: I hope he doesn't cut his hand with those scissors.   Caption: A man with a large dog sitting on a park bench.  Caption:
# caption: A bed with a white canopy.
#  91%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████               | 91/100 [01:36<00:09,  1.02s/it]
# query:   Caption: A little boy sitting on the side door of a car looking at a zebra.   Caption: A kitten sleeps underneath a table with two chairs.   Caption: A guy is showing off his surfing prowess.   Caption: A boat floating along a pier with people sitting on it.   Caption: A man standing in a room holding a game controller.   Caption: A living room filled with lots of furniture.   Caption: A couple of sheep standing next to each other.   Caption: A young boy and young girl holding toothbrushes in their mouths.  Caption:
# caption: A woman is lying in a hospital bed with medical equipment around her.
#  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋             | 92/100 [01:37<00:07,  1.01it/s]
# query:   Caption: A man holding a box with a pizza inside of it.   Caption: A group of people gathered in a grassy field   Caption: three street lamps in front of a clock tower   Caption: Two cats getting into a sink in a bathroom    Caption: A cut in half chili dog next to a salad.   Caption: A man on a motor bike going around a race track.   Caption: A man reaching low to hit a tennis ball   Caption: A tub sitting in a bathroom next to a  toilet.  Caption:
# caption: A pizza on a cutting board.
#  93%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍           | 93/100 [01:38<00:07,  1.04s/it]
# query:   Caption: Group of chocolate covered strawberries on square plate.   Caption: A goalie standing in front of a soccer goal.   Caption: A bear is hugging a leg in tights with cherries on them.   Caption: Two people laying on top of green grass under a white umbrella.   Caption: A gril is surfing waves in the ocean.   Caption: A glass of Orange juice next to a juicer   Caption: two men feeding each other a piece of a cake   Caption: A girl holding a soccer ball with other players around her.  Caption:
# caption: A person is surfing on a wave in the ocean.
#  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████          | 94/100 [01:39<00:06,  1.02s/it]
# query:   Caption: A couple of green street signs mounted to the top of a pole.   Caption: A flock of birds flying over a tall mountain.   Caption: A passenger bus near a bus stop, people next to it.   Caption: A boy in red shirt holding a baseball bat.   Caption: A row of ovens sitting inside of a warehouse.   Caption: A group of people standing around a elephant.   Caption: a couple of people that are on a baseball field   Caption: A blue motor scooter parked in front of a brick building.  Caption:
# caption: A young boy sleeping on a bed.
#  95%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋        | 95/100 [01:40<00:05,  1.03s/it]
# query:   Caption: Three bears swimming in a rushing river surrounded by greenery.   Caption: A spatula lifting up a slice of pizza from a tray   Caption: A person is taken in this very picture.
#    Caption: A water buffalo with long horns standing in a wooded area behind a wire fence.   Caption: Two pictures of people eating some pizza together.   Caption: A person on a skateboard attempting a jump   Caption: A man's hand is reaching toward a refrigerator.   Caption: Modern living room interior with many green plants  Caption:
# caption: A wedding photo of a bride and groom.
#  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎      | 96/100 [01:42<00:04,  1.13s/it]
# query:   Caption: A small elephant licking a blue metal fence.   Caption: A woman wearing a shirt with pictures of dogs while she holds a dog.   Caption: A young man on a skateboard grinds on a concrete ledge.   Caption: Some very pretty brown cows eating near a fence.   Caption: A desktop computer sitting on top of  desk.   Caption: Two woman sharing an umbrella as they walk   Caption: A cat lays on a quilt on an unmade bad.    Caption: A very cute giraffe sticking out its tongue.  Caption:
# caption: A man in a white coat stands in front of a pink bus with the word "Lover
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████     | 97/100 [01:43<00:03,  1.10s/it]
# query:   Caption: The boat is traveling down the narrow canal.   Caption: Men sit on a bench in front of a shop and one has a hat and a cane.   Caption: People walk near cows that eat on the side of a hill.   Caption: Pizza being sliced by pizza cutters on wood board.   Caption: A surfer on a beach holding his surfboard watching another surfer ride a wave.   Caption: A person cutting an opening in a box with some scissors.   Caption: A man stands by a horse in a forest setting.   Caption: A colorful arrangement of flowers and plants on a front porch.  Caption:
# caption: A young girl eating a slice of pizza.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 98/100 [01:44<00:02,  1.10s/it]
# query:   Caption: A man is laying down while playing a video game.   Caption: a little blue vase with a blue flower by a vent   Caption: some food is sitting next to a reader on a table   Caption: An airplane landing and one about to take off.   Caption: A woman standing next to a variety of green and yellow fruit.    Caption: a number of cows  walking across a road   Caption: Player at home plate preparing to swing at ball during game.   Caption: A boy standing in tall grass flying a kite.  Caption:
# caption: A room with a chair, mirror, and other furniture.
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎ | 99/100 [01:45<00:01,  1.07s/it]
# query:   Caption: A boy holding a baseball and waring a baseball uniform.   Caption: A stunning black and white photo of a toilet seat in the streets.   Caption: A man posing for a picture beside his bike.    Caption: a guy that is on a skateboard on a ramp   Caption: A truck is approaching an intersection with a green light   Caption: A cat laying on top of a laptop.   Caption: A man is pitching a baseball to a batter.   Caption: A cat sitting on a desk in front of a computer.  Caption:
# caption: A slice of pizza with sauce on it.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:46<00:00,  1.06s/it]
# query:   Caption: People travelling on bicycles on a city street.    Caption: a baker putting some food in a cooler   Caption: A passenger train that is traveling down railroad tracks.   Caption: A large group of alike motorcycles are lined up.   Caption: A grey and white cat laying on a bed with a television in the background.   Caption: A large polar bear playing with two balls.   Caption: A man that is holding on to a racquet.   Caption: A green traffic light above a street with a car on coming.  Caption:
# caption: A tennis player is hitting a ball with a racquet.

# %%
item = val_dataset[4]
item
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x388>,
#  'caption': 'a blue bike parked on a side walk ',
#  'image_id': 174482}

# %%
icl_demonstrs = get_n_shot_demonstrations(item, n, use_random, n_random)
querys, im_lists = construct_vqa_query([item], icl_demonstrs)

# %%
querys
# Out:
# ['  Image of a gray bicycle is locked to some metal doors   Image of Bike chained to pole along side a busy street  Image of ']

# %%
im_lists[0][2]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x388>

# %%
querys[0], im_lists[0]
# Out:
# ('  Image of A run down kitchen filled with lots of construction equipment.   Image of A white refrigerator freezer sitting next to a stone wall.  Image of ',
#  [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>])

# %%
get_output_for_query(querys[0], im_lists[0],"llava_v1",50)
# Out:
# torch.Size([3, 3, 384, 384])
# A kitchen with a rustic and old-fashioned design, featuring a stone wall and a wooden table. There is a white refrigerator freezer, a wooden cabinet, and various kitchen utensils hanging on the wall.
# 'A kitchen with a rustic and old-fashioned design, featuring a stone wall and a wooden table. There is a white refrigerator freezer, a wooden cabinet, and various kitchen utensils hanging on the wall.'

# %%
from PIL import Image
import requests
import torch

"""
Step 1: Load images
"""
demo_image_one = Image.open(
    requests.get(
        "http://images.cocodataset.org/val2017/000000039769.jpg", stream=True
    ).raw
)

demo_image_two = Image.open(
    requests.get(
        "http://images.cocodataset.org/test-stuff2017/000000028137.jpg",
        stream=True
    ).raw
)

query_image = Image.open(
    requests.get(
        "http://images.cocodataset.org/test-stuff2017/000000028352.jpg", 
        stream=True
    ).raw
)
query = "An image of two cats.  An image of a bathroom sink.  An image of"

# %%
get_output_for_query(query, [demo_image_one, demo_image_two, query_image], "llava_v1")
# Out:
# torch.Size([3, 3, 384, 384])
# a table full of food.
# 'a table full of food.'

# %%
# !python vila_e2e_captioning_coco.py --n_shots 4
# Out:
# /home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# [2024-11-17 04:45:44,913] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/open_clip/factory.py:372: UserWarning: These pretrained weights were trained with QuickGELU activation but the model config does not have that enabled. Consider using a model config with a "-quickgelu" suffix or enable with a flag.
#   warnings.warn(
# /home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 21 files: 100%|█████████████████████| 21/21 [00:00<00:00, 62203.66it/s]
# Loading checkpoint shards: 100%|██████████████████| 6/6 [00:29<00:00,  4.97s/it]
# Namespace(model_name_or_path='Efficient-Large-Model/VILA1.5-13b', n_shots=4, use_random=False, n_random=0)
#   0%|                                                  | 0/5000 [00:00<?, ?it/s]/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/transformers/generation/utils.py:1295: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
#   0%|                                       | 16/5000 [00:15<1:19:51,  1.04it/s]^C
#   0%|                                       | 16/5000 [00:16<1:24:07,  1.01s/it]
# Traceback (most recent call last):
#   File "/home/asureddy_umass_edu/cs682/VILA/llava/eval/vila_e2e_captioning_coco.py", line 183, in <module>
#     out = get_output(val_dataset[i],n,use_random, n_random)
#   File "/home/asureddy_umass_edu/cs682/VILA/llava/eval/vila_e2e_captioning_coco.py", line 164, in get_output
#     return get_output_for_query(querys[0], im_lists[0],"llava_v1",20)
#   File "/home/asureddy_umass_edu/cs682/VILA/llava/eval/vila_e2e_captioning_coco.py", line 105, in get_output_for_query
#     output_ids = model.generate(
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/asureddy_umass_edu/cs682/VILA/llava/model/llava_arch.py", line 874, in generate
#     outputs = self.llm.generate(inputs_embeds=inputs_embeds, attention_mask=attention_mask, **generation_kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/transformers/generation/utils.py", line 1525, in generate
#     return self.sample(
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/transformers/generation/utils.py", line 2622, in sample
#     outputs = self(
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py", line 1183, in forward
#     outputs = self.model(
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py", line 1070, in forward
#     layer_outputs = decoder_layer(
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py", line 798, in forward
#     hidden_states, self_attn_weights, present_key_value = self.self_attn(
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/transformers/models/llama/modeling_llama.py", line 741, in forward
#     attn_output = self.o_proj(attn_output)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/asureddy_umass_edu/.conda/envs/vila/lib/python3.10/site-packages/torch/nn/modules/linear.py", line 116, in forward
#     return F.linear(input, self.weight, self.bias)
# KeyboardInterrupt
